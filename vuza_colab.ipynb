# %% [markdown]
# # 🎬 VUZA2 — Video Utility for Zero-cost Automation
# ### Free AI Video Creator & Money Printer Tool
#
# **Built by [Ali R.](https://github.com/AliRash3ed)**
#
# > ⚡ **TIP:** Use the T4 GPU runtime for faster video processing!
# > Go to `Runtime → Change runtime type → T4 GPU`
#
# ---

# %% [markdown]
# ## 1️⃣ Clone & Install (Run this cell first)

# %%
# Clone VUZA2
# !git clone https://github.com/anaseeem/VUZA2.git
# %cd VUZA2

# Install all dependencies
# !pip install -r requirements.txt -q

# Install Playwright browsers
# !playwright install chromium
# !playwright install-deps

# Install pyngrok for public URL
# !pip install pyngrok -q

print("\n✅ VUZA2 installed successfully!")
# Out:
# Cloning into 'VUZA2'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 88 (delta 31), reused 19 (delta 19), pack-reused 38 (from 1)
# Receiving objects: 100% (88/88), 1.04 MiB | 20.88 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/VUZA2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.7/183.7 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 82.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 14.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2️⃣ Start VUZA2 Server
#
# This will start the server and give you a **public URL** to access VUZA2 from any browser.
#
# > 🎯 The T4 GPU makes video processing **MUCH faster**!
# > You also get Google's fast internet for downloading media.

# %%
import subprocess
import threading
import time
from google.colab import userdata
from pyngrok import ngrok

# Start the VUZA2 server in background
server = subprocess.Popen(['python', 'app.py'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
time.sleep(3)

ngrok.set_auth_token(userdata.get('NGROK_AUTHTOKEN'))

# Create public URL
public_url = ngrok.connect(8000)
print(f"\n🚀 VUZA2 is LIVE!")
print(f"\n🌐 Open this URL in your browser:")
print(f"\n   👉 {public_url}")
print(f"\n📌 Keep this cell running! Close the tab to stop.")
print(f"\n💡 TIP: Add your API keys in the ⚙️ Settings panel")

# Keep alive
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    ngrok.kill()
    server.terminate()
    print("\n🛑 Server stopped.")
